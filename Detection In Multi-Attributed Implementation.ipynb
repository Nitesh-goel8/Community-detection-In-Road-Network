# %%
# !wget https://snap.stanford.edu/data/email-Eu-core.txt.gz
# !gunzip email-Eu-core.txt.gz
# Out:
# --2026-03-16 18:25:14--  https://snap.stanford.edu/data/email-Eu-core.txt.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79754 (78K) [application/x-gzip]
# Saving to: ‘email-Eu-core.txt.gz’
#
# email-Eu-core.txt.g 100%[===================>]  77.88K   416KB/s    in 0.2s
#
# 2026-03-16 18:25:14 (416 KB/s) - ‘email-Eu-core.txt.gz’ saved [79754/79754]

# %%
# !pip install networkx python-louvain
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.6.1)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.12/dist-packages (0.16)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from python-louvain) (2.0.2)

# %%
import networkx as nx

G = nx.read_edgelist("email-Eu-core.txt", nodetype=int)

print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())
# Out:
# Nodes: 1005
# Edges: 16706

# %%
import community as community_louvain

partition = community_louvain.best_partition(G)

print("Number of communities:", len(set(partition.values())))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1523/1836502840.py in <cell line: 0>()
#       1 import community as community_louvain
#       2
# ----> 3 partition = community_louvain.best_partition(G)
#       4
#       5 print("Number of communities:", len(set(partition.values())))
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
# !pip uninstall community -y
# Out:
# Found existing installation: community 1.0.0b1
# Uninstalling community-1.0.0b1:
#   Successfully uninstalled community-1.0.0b1

# %%
# !pip install python-louvain
# Out:
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.12/dist-packages (0.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from python-louvain) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from python-louvain) (2.0.2)

# %%
import community.community_louvain as community_louvain

# %%
partition = community_louvain.best_partition(G)

print("Number of communities:", len(set(partition.values())))
# Out:
# Number of communities: 27

# %%
modularity = community_louvain.modularity(partition, G)

print("Modularity score:", modularity)
# Out:
# Modularity score: 0.43334462919395805

# %%
import networkx as nx
import community.community_louvain as community_louvain

# load graph
G = nx.read_edgelist("email-Eu-core.txt", nodetype=int)

print("Nodes:", G.number_of_nodes())
print("Edges:", G.number_of_edges())

# run Louvain
partition = community_louvain.best_partition(G)

print("Communities:", len(set(partition.values())))

# evaluation
modularity = community_louvain.modularity(partition, G)

print("Modularity:", modularity)
# Out:
# Nodes: 1005
# Edges: 16706
# Communities: 27
# Modularity: 0.41907730761508444
